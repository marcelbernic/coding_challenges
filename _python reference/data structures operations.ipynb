# %% [markdown]
# # Content
#
# * [Various](#Various)
# * [Dictionary](#Dictionary)
# * [Set](#Set)
# * [Deque](#Deque)
# * [List](#List)
# * [Tuple](#Tuple)
# * [Heap](#Heap)

# %% [markdown]
# # Various
#
# We use 'while' loop when we want to control how we increment the indexes (ex: one_away_diff problem)
# We use 'for' loop when we know we want to increment the index at each iteration

# %%
# reverse
# for i in reversed(range(10)):
#     print(i)

# loop in reverse
a = [1, 2, 3, 4, 5]
# for i in range(len(a)-1, -1, -1):
#     print(a[i])
for i in reversed(range(len(a))):
    print(a[i])
    
# while checks for null
# while (l1 is not None) and (l2 is not None): == while l1 and l2:

# Function within function:
def testInnerFunction(parameter1):

    def inner(x):
        print("It works ", x)

    inner(parameter1)

testInnerFunction(5)

# inifinit value
max_sum = float('-inf')

# nonlocal 
# this is used to declare a variable in a innerfunction that is in other scope (Binary Tree Maximum Path Sum)

# zip
# a = ("John", "Charles", "Mike")
# b = ("Jenny", "Christy", "Monica", "Vicky")
# zip(a, b) -> (('John', 'Jenny'), ('Charles', 'Christy'), ('Mike', 'Monica'))

# one diff away
def match(s1, s2):
    ok = False

    for c1, c2 in zip(s1, s2):
        if c1 != c2:
            if ok:
                return False
            else:
                ok = True

    return ok

print(match('abc', 'abc'))

# LAMBDA functions !!!
points = [[0, 0], [1, 2], [43,2], [4,4]]
points.sort(key = lambda P: P[0]**2 + P[1]**2)
print(points)

# sort with multiple criteria using lambda (reorder data in logs problem):
    #  if we are asked to sort the students first by the grade, then by the age, we can simply 
    #  return the compound key (student.grade, student.age), as follows
# sorted(student_objects, key=lambda student: student.age) -> ONLY BY AGE
# sorted(student_objects, key=lambda student: (student.grade, student.age)) -> BY GRADE THEN AGE
    

# Nice one-liner
# Sanitize a paragraph of exclamation signs in order to separate words
paragraph = "This, is a ! para@ lol2'"
paragraph_normal = ''.join([c.lower() if c.isalnum() else ' ' for c in paragraph])
print(paragraph_normal.split())
# Out:
# 5
# 4
# 3
# 2
# 1
# It works  5
# False
# [[0, 0], [1, 2], [4, 4], [43, 2]]
# ['this', 'is', 'a', 'para', 'lol2']

# %% [markdown]
# # Dictionary

# %% [markdown]
# ## methods
#
# ![Screen%20Shot%202021-02-07%20at%2010.57.10%20PM.png](attachment:Screen%20Shot%202021-02-07%20at%2010.57.10%20PM.png)

# %% [markdown]
# ! IMPORTANT: There is a structure called ordered dictionary, it combines behind both hashmap and linked list.
# In Python this structure is called OrderedDict and in Java LinkedHashMap.

# %%
# Dictionary basic operations
d = {
    "a": 1,
    "b": 2,
    "c": 3,
    "d": 4,
    "e": 5
}

print(d)

print("Search element by key:")
print(d['e'])

print("Get all keys set:")
print(d.keys())

print("Get all values set:")
print(d.values())

print("Get all items as a tuple:")
print(d.items())

print("Add/Set a key<->value:")
d["a"] = 9
d["f"] = 6
print(d)

print("Delete entry:")
del d["f"]
print(d)

print("Convert key set in a list or tuple:")
print(list(d.keys()))
print(tuple(d.keys()))

print("True copy of a dictionary:")
d1 = d         # just a reference, if we modiy 'd1' the 'd' will be modified too
d2 = d.copy()  # deep copy, if we modify 'd2' the 'd' will not be modified too

print("Loop through a dictionary:")
for key in d:
    print(key, d[key])
print("--------------------")
for key, value in d.items():
    print(key, value)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
# Search element by key:
# 5
# Get all keys set:
# dict_keys(['a', 'b', 'c', 'd', 'e'])
# Get all values set:
# dict_values([1, 2, 3, 4, 5])
# Get all items as a tuple:
# dict_items([('a', 1), ('b', 2), ('c', 3), ('d', 4), ('e', 5)])
# Add/Set a key<->value:
# {'a': 9, 'b': 2, 'c': 3, 'd': 4, 'e': 5, 'f': 6}
# Delete entry:
# {'a': 9, 'b': 2, 'c': 3, 'd': 4, 'e': 5}
# Convert key set in a list or tuple:
# ['a', 'b', 'c', 'd', 'e']
# ('a', 'b', 'c', 'd', 'e')
# True copy of a dictionary:
# Loop through a dictionary:
# a 9
# b 2
# c 3
# d 4
# e 5
# --------------------
# a 9
# b 2
# c 3
# d 4
# e 5

# %% [markdown]
# DEFAULTDICT
#
# from collections import defaultdict
#
# defaultdict means that if a key is not found in the dictionary, then instead of a KeyError being thrown, a new entry is created. The type of this new entry is given by the argument of defaultdict.

# %%
class GNode(object):
    """  data structure represent a vertex in the graph."""
    def __init__(self):
        self.inDegrees = 0
        self.outNodes = []

class Solution(object):
    def canFinish(self, numCourses, prerequisites):
        """
        :type numCourses: int
        :type prerequisites: List[List[int]]
        :rtype: bool
        """
        from collections import defaultdict, deque
        # key: index of node; value: GNode
        graph = defaultdict(GNode)

        totalDeps = 0
        for relation in prerequisites:
            nextCourse, prevCourse = relation[0], relation[1]
            graph[prevCourse].outNodes.append(nextCourse)
            graph[nextCourse].inDegrees += 1
            totalDeps += 1
        
        print(graph)

# If we don't use defaultdict, each time we want to add in the dictonary
# we need to verify before if the item is not there and add an empty item
# ex:
#            if x not in indegreeMap.keys():
#                indegreeMap[x] = set()
#            indegreeMap[x].add(y)

# %% [markdown]
# # Set

# %% [markdown]
# ## methods
# ![Screen%20Shot%202021-02-07%20at%2010.54.55%20PM.png](attachment:Screen%20Shot%202021-02-07%20at%2010.54.55%20PM.png)

# %%
# Set

# Demonstrate set operations on unique letters from two words

a = set('abracadabra')
b = set('alacazam')
a                                  # unique letters in a
# {'a', 'r', 'b', 'c', 'd'}
a - b                              # letters in a but not in b
# {'r', 'd', 'b'}
a | b                              # letters in a or b or both
# {'a', 'c', 'r', 'd', 'b', 'm', 'z', 'l'}
a & b                              # letters in both a and b
# {'a', 'c'}
a ^ b                              # letters in a or b but not both
# {'r', 'd', 'b', 'm', 'z', 'l'}
a.remove('a')
a.add('lo')
print(a)
# Out:
# {'b', 'lo', 'c', 'd', 'r'}
# 'b'

# %% [markdown]
# # Deque

# %%
# Deque - designed to have fast appends and pops from both ends (as a data structure)
    # append
    # appendleft
    # pop
    # popleft
# Also Queue but more used in multithreading...
from collections import deque

items = deque([1, 2])
items.append(3)        # deque == [1, 2, 3]
items.rotate(1)        # The deque is now: [3, 1, 2]
items.rotate(-1)       # Returns deque to original state: [1, 2, 3]
item = items.popleft() # deque == [2, 3]
item = items.pop()     # deque == [2]
print(items)

# Queue
from queue import Queue
queue = Queue()
queue.put(1)
print(queue.get())
# Out:
# deque([2])
# 1

# %% [markdown]
# # List

# %% [markdown]
# ## methods
#
# ![Screen%20Shot%202021-02-07%20at%2010.59.33%20PM.png](attachment:Screen%20Shot%202021-02-07%20at%2010.59.33%20PM.png)

# %%
### Initialize
# with None items (list comprehenstion)
row = [None for x in range(4 + 1)]
# with multiplication
count = [0] * 26

# insert
list1 = ['a', 'b', 'c']
list1.insert(0, 'z')
print(list1)

# List as stack
    # append -> on the right side
    # pop    -> from the right side

stack = [3, 4, 5]
print(stack)
print(stack)
stack.append(6)
stack.append(7)
# [3, 4, 5, 6, 7]
stack.pop() # -> 7
# [3, 4, 5, 6]
stack.pop() # -> 6
stack.pop() # -> 5
# [3, 4]

# List as queue
    # append -> on the right side
    # pop(0) -> remove from the left side
queue = []
queue.append(1)
queue.append(2)
queue.append(3)
print(queue)
# Out:
# ['z', 'a', 'b', 'c']
# [3, 4, 5]
# [3, 4, 5]
# [1, 2, 3]

# %% [markdown]
# # Tuple

# %% [markdown]
# ## methods
#
# ![Screen%20Shot%202021-02-07%20at%2011.00.43%20PM.png](attachment:Screen%20Shot%202021-02-07%20at%2011.00.43%20PM.png)

# %% [markdown]
# # Heap

# %%
# create -> O(n)
# replace -> O(logn)
# print -> O(n)

import heapq

# heapify - This function converts a regular list to a heap. In the resulting heap the smallest element gets pushed to the index position 0. But rest of the data elements are not necessarily sorted.
# heappush – This function adds an element to the heap without altering the current heap.
# heappop - This function returns the smallest data element from the heap.
    # To access the smallest item without popping it, use heap[0].
# heapreplace – This function replaces the smallest data element with a new value supplied in the function.

H = [21,1,45,78,3,5]
# Use heapify to rearrange the elements
heapq.heapify(H)
print(H)
heapq.heappop(H)
print(H)
heapq.heappush(H, 23)
print(H)
heapq.heapreplace(H, 99)
print(H)
# Out:
# [1, 3, 5, 78, 21, 45]
# [3, 21, 5, 78, 45]
# [3, 21, 5, 78, 45, 23]
# [5, 21, 23, 78, 45, 99]
