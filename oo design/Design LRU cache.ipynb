# %% [markdown]
# ## Design an LRU cache

# %%
class Node(object):
    def __init__(self, results):
        self.results = results
        self.next = next
        
class LinkedList(object):
    def __init__(self):
        self.head = None
        self.tail = None
        
    def move_to_front(self, node):
        print("To implement")
    def append_to_front(self, node):
        print("To implement")
    def remove_from_tail(self):
        print("To implement")
        
        
class Cache(object):
    
    def __init__(self, MAX_SIZE):
        self.MAX_SIZE = MAX_SIZE
        self.size = 0
        self.lookup = {} # key: query, value: node
        self.linked_list = LinkedList()
        
    def get(self, query):
        node = self.lookup[query]
        if node is None:
            return None
        self.linked_list.move_to_front(node)
        return node.results
    
    def set(self, results, query):
        node = self.lookup[query]
        if node is not None:
            # Key exists in cache, update the value
            node.results = results
            self.linked_list.move_to_front(node)
        else:
            # Key does not exist in cache
            if self.size == self.MAX_SIZE:
                self.lookup.pop(self.linked_list.tail.query, None)
                self.linked_list.remove_from_tail()
            else:
                size += 1
            # Add new key and value
            new_node = Node(results)
            self.linked_list.append_to_front(new_node)
            self.lookup[query] = new_node

# %% [markdown]
# ### Leet code example
#
# Design a data structure that follows the constraints of a Least Recently Used (LRU) cache.
#
# Implement the LRUCache class:
#
#     LRUCache(int capacity) Initialize the LRU cache with positive size capacity.
#     int get(int key) Return the value of the key if the key exists, otherwise return -1.
#     void put(int key, int value) Update the value of the key if the key exists. Otherwise, add the key-value pair to the cache. If the number of keys exceeds the capacity from this operation, evict the least recently used key.
#
# The functions get and put must each run in O(1) average time complexity.
#
#
#
# Example 1:
#
# Input
# ["LRUCache", "put", "put", "get", "put", "get", "put", "get", "get", "get"]
# [[2], [1, 1], [2, 2], [1], [3, 3], [2], [4, 4], [1], [3], [4]]
# Output
# [null, null, null, 1, null, -1, null, -1, 3, 4]
#
# Explanation
# LRUCache lRUCache = new LRUCache(2);
# lRUCache.put(1, 1); // cache is {1=1}
# lRUCache.put(2, 2); // cache is {1=1, 2=2}
# lRUCache.get(1);    // return 1
# lRUCache.put(3, 3); // LRU key was 2, evicts key 2, cache is {1=1, 3=3}
# lRUCache.get(2);    // returns -1 (not found)
# lRUCache.put(4, 4); // LRU key was 1, evicts key 1, cache is {4=4, 3=3}
# lRUCache.get(1);    // return -1 (not found)
# lRUCache.get(3);    // return 3
# lRUCache.get(4);    // return 4
#
#
#
# Constraints:
#
#     1 <= capacity <= 3000
#     0 <= key <= 104
#     0 <= value <= 105
#     At most 2 * 105 calls will be made to get and put.

# %%
class LRUCache:

    def __init__(self, capacity: int):
        self.MAX_SIZE = capacity
        self.size = 0
        self.cache = {}
        self.lru_list =[]
        
    def get(self, key: int) -> int:
        if key not in self.cache:
            return -1
        res = self.cache[key]
        # move to front of the lru_list before returning the value from cache
        self.lru_list.pop(self.lru_list.index((key,res)))
        self.lru_list.insert(len(self.lru_list), (key,res))
        return res
        
    def put(self, key: int, value: int) -> None:
        if key in self.cache:
            old_value = self.cache[key]
            # Key exists in cache
            self.cache[key] = value
            # move to front of the lru_list
            self.lru_list.pop(self.lru_list.index((key,old_value)))
            self.lru_list.insert(len(self.lru_list), (key,value))
        else:
            # Key does not exist in cache
            if self.size == self.MAX_SIZE:
                self.cache.pop(self.lru_list[0][0], None)
                self.lru_list.pop(0)
            else:
                self.size += 1
            # Add key to cache
            self.cache[key] = value
            self.lru_list.insert(len(self.lru_list), (key,value))


# Your LRUCache object will be instantiated and called as such:
# obj = LRUCache(capacity)
# param_1 = obj.get(key)
# obj.put(key,value)

# %% [markdown]
# Leet code version example:

# %%
# ["LRUCache","put","put","get","put","get","put","get","get","get"]
# [[2],[1,1],[2,2],[1],[3,3],[2],[4,4],[1],[3],[4]]

obj = LRUCache(2)
obj.put(1, 1)
obj.put(2, 2)
print(obj.get(3))
# ...
# Out:
# -1
